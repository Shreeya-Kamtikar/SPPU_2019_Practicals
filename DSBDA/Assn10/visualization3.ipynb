# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import load_iris

# %%
data = load_iris()

# %%
df = pd.DataFrame()
df[data['feature_names']] = data['data']
df['label'] = data['target']

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    label
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      label
# 145      2
# 146      2
# 147      2
# 148      2
# 149      2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   label              150 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 5.4 KB

# %%
sns.histplot(df,x='sepal length (cm)',color='lightblue')
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='Count'>

# %%
sns.histplot(df,x='sepal width (cm)',color='lightblue')
# Out:
# <Axes: xlabel='sepal width (cm)', ylabel='Count'>

# %%
sns.histplot(df,x='petal length (cm)',color='lightblue')
# Out:
# <Axes: xlabel='petal length (cm)', ylabel='Count'>

# %%
sns.histplot(df,x='sepal length (cm)',color='lightblue')
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='Count'>

# %%
sns.boxplot(df, x='label',y='sepal length (cm)')
# Out:
# <Axes: xlabel='label', ylabel='sepal length (cm)'>

# %%
sns.boxplot(df, x='label',y='sepal width (cm)')
# Out:
# <Axes: xlabel='label', ylabel='sepal width (cm)'>

# %%
sns.boxplot(df, x='label',y='petal length (cm)')
# Out:
# <Axes: xlabel='label', ylabel='petal length (cm)'>

# %%
sns.boxplot(df, x='label', y='petal width (cm)')
# Out:
# <Axes: xlabel='label', ylabel='petal width (cm)'>
